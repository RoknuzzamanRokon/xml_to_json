# %% [markdown]
# ## Import libarey for create json file

# %%
import requests
import xmltodict
import json

# %% [markdown]
# ### Define the URL for the XML data

# %%
url = "https://affiliatefeed.agoda.com/datafeeds/feed/getfeed?apikey=3ce93b4c-3bb4-4f0f-91c9-6e861c2bf7fb&mhotel_id=16075260&feed_id=19"

# Fetch the XML data from the URL
response = requests.get(url)

# %%
if response.status_code == 200:
    # Parse XML to OrderedDict
    xml_data = response.content
    data_dict = xmltodict.parse(xml_data)
    
    # Convert OrderedDict to JSON
    json_data = json.dumps(data_dict, indent=4)
    
    # Print JSON data
    print(json_data)
else:
    print("Failed to retrieve XML data")
# Out:
# {
#     "Hotel_feed_full": {
#         "@xmlns:xs": "http://www.w3.org/2001/XMLSchema",
#         "@xmlns:xsi": "http://www.w3.org/2001/XMLSchema-instance",
#         "hotels": {
#             "hotel": {
#                 "hotel_id": "16075260",
#                 "hotel_name": "Changsha Qintian\u00b7Yue Hotel",
#                 "hotel_formerly_name": null,
#                 "translated_name": "Changsha Qintian\u00b7Yue Hotel",
#                 "star_rating": "4.0",
#                 "continent_id": "2",
#                 "country_id": "191",
#                 "city_id": "79709",
#                 "area_id": "482064",
#                 "longitude": "113.03109741210938",
#                 "latitude": "28.1818904876709",
#                 "hotel_url": "https://www.agoda.com/partners/partnersearch.aspx?hid=16075260",
#                 "popularity_score": "652418",
#                 "remark": null,
#                 "number_of_reviews": "0",
#                 "rating_average": "0",
#                 "child_and_extra_bed_policy": {
#                     "infant_age": "0",
#                     "children_age_from": "0",
#                     "children_age_to": "0",
#                     "children_stay_free": "false",
#                     "min_guest_age": "0"
#                 },
#                 "accommodation_type": "Hotel",
#                 "nationality_restrictions": null
#             }
#         },
#         "addresses": {
#             "address": [
#                 {
#                     "hotel_id": "16075260",
#                     "address_type": "English address",
#                     "address_line_1": "No. 207 Wanjiali Middle Road",
#                     "address_line_2": null,
#                     "postal_code": "410007",
#                     "state": "Hunan",
#                     "city": "Changsha",
#                     "country": "China"
#                 },
#                 {
#                     "hotel_id": "16075260",
#                     "address_type": "Local language",
#                     "address_line_1": "\u4e07\u5bb6\u4e3d\u4e2d\u8def207\u53f7",
#                     "address_line_2": null,
#                     "postal_code": "410007",
#                     "state": "\u6e56\u5357",
#                     "city": "\u957f\u6c99",
#                     "country": "\u4e2d\u56fd"
#                 }
#             ]
#         },
#         "hotel_descriptions": {
#             "hotel_description": {
#                 "hotel_id": "16075260",
#                 "overview": null,
#                 "snippet": null
#             }
#         },
#         "facilities": null,
#         "pictures": {
#             "picture": [
#                 {
#                     "hotel_id": "16075260",
#                     "picture_id": "594670771",
#                     "caption": null,
#                     "caption_translated": null,
#                     "URL": "https://pix8.agoda.net/property/16075260/0/527c1a179a675d5d3a28e7146901da6b.jpeg?ce=0&s=312x"
#                 },
#                 {
#                     "hotel_id": "16075260",
#                     "picture_id": "594670796",
#                     "caption": null,
#                     "caption_translated": null,
#                     "URL": "https://pix8.agoda.net/property/16075260/0/a4e8b7d3ffb1e520861eab641ffa3d19.jpeg?ce=0&s=312x"
#                 },
#                 {
#                     "hotel_id": "16075260",
#                     "picture_id": "594670797",
#                     "caption": null,
#                     "caption_translated": null,
#                     "URL": "https://pix8.agoda.net/property/16075260/0/16d958102bb151cb3a9ace8fe5984ccc.jpeg?ce=0&s=312x"
#                 },
#                 {
#                     "hotel_id": "16075260",
#                     "picture_id": "594670769",
#                     "caption": null,
#                     "caption_translated": null,
#                     "URL": "https://pix8.agoda.net/property/16075260/0/d437aa75f8f39ad013c470c8397659f9.jpeg?ce=0&s=312x"
#                 },
#                 {
#                     "hotel_id": "16075260",
#                     "picture_id": "594670770",
#                     "caption": null,
#                     "caption_translated": null,
#                     "URL": "https://pix8.agoda.net/property/16075260/0/d11a919e1c423bbc99e4c7f847e0665b.jpeg?ce=0&s=312x"
#                 },
#                 {
#                     "hotel_id": "16075260",
#                     "picture_id": "165013478",
#                     "caption": null,
#                     "caption_translated": null,
#                     "URL": "https://pix8.agoda.net/property/16075260/202855782/ad2c3882db2a9626ddac960ff18cd8d6.jpg?ca=12&ce=1&s=312x"
#                 },
#                 {
#                     "hotel_id": "16075260",
#                     "picture_id": "594670762",
#                     "caption": null,
#                     "caption_translated": null,
#                     "URL": "https://pix8.agoda.net/property/16075260/0/85bb6d11af4ac903a390cf9c1feb8522.jpeg?ce=0&s=312x"
#                 },
#                 {
#                     "hotel_id": "16075260",
#                     "picture_id": "594670768",
#                     "caption": null,
#                     "caption_translated": null,
#                     "URL": "https://pix8.agoda.net/property/16075260/0/4d2e4c93b7a1725343243e71471705ab.jpeg?ce=0&s=312x"
#                 },
#                 {
#                     "hotel_id": "16075260",
#                     "picture_id": "158710341",
#                     "caption": null,
#                     "caption_translated": null,
#                     "URL": "https://pix8.agoda.net/property/16075260/202855782/41c5eda4c467c78d055b7f712eed36dd.jpg?ca=12&ce=1&s=312x"
#                 },
#                 {
#                     "hotel_id": "16075260",
#                     "picture_id": "594670764",
#                     "caption": null,
#                     "caption_translated": null,
#                     "URL": "https://pix8.agoda.net/property/16075260/0/37950c5f71c7fa26ac2fcb3935f83e5f.jpeg?ce=0&s=312x"
#                 },
#                 {
#                     "hotel_id": "16075260",
#                     "picture_id": "594670766",
#                     "caption": null,
#                     "caption_translated": null,
#                     "URL": "https://pix8.agoda.net/property/16075260/0/a7e2bafb45133196ff95207292246931.jpeg?ce=0&s=312x"
#                 },
#                 {
#                     "hotel_id": "16075260",
#                     "picture_id": "169203100",
#                     "caption": null,
#                     "caption_translated": null,
#                     "URL": "https://pix8.agoda.net/property/16075260/202855844/2200fa1050e16b828b1cb47046cee7b9.jpg?ca=12&ce=1&s=312x"
#                 },
#                 {
#                     "hotel_id": "16075260",
#                     "picture_id": "594670778",
#                     "caption": null,
#                     "caption_translated": null,
#                     "URL": "https://pix8.agoda.net/property/16075260/0/404261179fc2acb2d751ec1cec43d2c2.jpeg?ce=0&s=312x"
#                 },
#                 {
#                     "hotel_id": "16075260",
#                     "picture_id": "594670765",
#                     "caption": null,
#                     "caption_translated": null,
#                     "URL": "https://pix8.agoda.net/property/16075260/0/2417199b18c8419b8cbcbdecea1dcee2.jpeg?ce=0&s=312x"
#                 },
#                 {
#                     "hotel_id": "16075260",
#                     "picture_id": "158710347",
#                     "caption": null,
#                     "caption_translated": null,
#                     "URL": "https://pix8.agoda.net/property/16075260/202
repeat1-tydcf",
#                     "standard_caption_translated": null,
#                     "max_occupancy_per_room": "2",
#                     "no_of_room": "0",
#                     "size_of_room": "0",
#                     "room_size_incl_terrace": "False",
#                     "views": null,
#                     "max_extrabeds": "1",
#                     "max_infant_in_room": "0",
#                     "hotel_room_type_picture": "https://pix8.agoda.net/property/16075260/0/527c1a179a675d5d3a28e7146901da6b.jpeg?ce=0&s=312x",
#                     "bed_type": null,
#                     "hotel_master_room_type_id": "0",
#                     "hotel_room_type_alternate_name": null,
#                     "shared_bathroom": "False",
#                     "gender": null
#                 },
#                 {
#                     "hotel_id": "16075260",
#                     "hotel_room_type_id": "757410705",
#                     "standard_caption": "Repeat1-Repeat1-tydcf",
#                     "standard_caption_translated": null,
#                     "max_occupancy_per_room": "2",
#                     "no_of_room": "0",
#                     "size_of_room": "0",
#                     "room_size_incl_terrace": "False",
#                     "views": null,
#                     "max_extrabeds": "1",
#                     "max_infant_in_room": "0",
#                     "hotel_room_type_picture": "https://pix8.agoda.net/property/16075260/0/527c1a179a675d5d3a28e7146901da6b.jpeg?ce=0&s=312x",
#                     "bed_type": null,
#                     "hotel_master_room_type_id": "763538940",
#                     "hotel_room_type_alternate_name": null,
#                     "shared_bathroom": "False",
#                     "gender": null
#                 },
#                 {
#                     "hotel_id": "16075260",
#                     "hotel_room_type_id": "962209265",
#                     "standard_caption": "Round-Bed Room",
#                     "standard_caption_translated": "Round-Bed Room",
#                     "max_occupancy_per_room": "2",
#                     "no_of_room": "0",
#                     "size_of_room": "0",
#                     "room_size_incl_terrace": "False",
#                     "views": null,
#                     "max_extrabeds": "1",
#                     "max_infant_in_room": "0",
#                     "hotel_room_type_picture": "https://pix8.agoda.net/property/16075260/0/527c1a179a675d5d3a28e7146901da6b.jpeg?ce=0&s=312x",
#                     "bed_type": null,
#                     "hotel_master_room_type_id": "0",
#                     "hotel_room_type_alternate_name": null,
#                     "shared_bathroom": "False",
#                     "gender": null
#                 },
#                 {
#                     "hotel_id": "16075260",
#                     "hotel_room_type_id": "345007343",
#                     "standard_caption": "Room Assigned on Arrival",
#                     "standard_caption_translated": null,
#                     "max_occupancy_per_room": "2",
#                     "no_of_room": "0",
#                     "size_of_room": "0",
#                     "room_size_incl_terrace": "False",
#                     "views": null,
#                     "max_extrabeds": "1",
#                     "max_infant_in_room": "0",
#                     "hotel_room_type_picture": "https://pix8.agoda.net/property/16075260/0/527c1a179a675d5d3a28e7146901da6b.jpeg?ce=0&s=312x",
#                     "bed_type": null,
#                     "hotel_master_room_type_id": "0",
#                     "hotel_room_type_alternate_name": null,
#                     "shared_bathroom": "False",
#                     "gender": null
#                 },
#                 {
#                     "hotel_id": "16075260",
#                     "hotel_room_type_id": "653965585",
#                     "standard_caption": "Room Assigned on Arrival",
#                     "standard_caption_translated": null,
#                     "max_occupancy_per_room": "2",
#                     "no_of_room": "0",
#                     "size_of_room": "0",
#                     "room_size_incl_terrace": "False",
#                     "views": null,
#                     "max_extrabeds": "1",
#                     "max_infant_in_room": "0",
#                     "hotel_room_type_picture": "https://pix8.agoda.net/property/16075260/0/527c1a179a675d5d3a28e7146901da6b.jpeg?ce=0&s=312x",
#                     "bed_type": null,
#                     "hotel_master_room_type_id": "345007343",
#                     "hotel_room_type_alternate_name": null,
#                     "shared_bathroom": "False",
#                     "gender": null
#                 },
#                 {
#                     "hotel_id": "16075260",
#                     "hotel_room_type_id": "856614941",
#                     "standard_caption": "Room Assigned on Arrival",
#                     "standard_caption_translated": null,
#                     "max_occupancy_per_room": "2",
#                     "no_of_room": "0",
#                     "size_of_room": "0",
#                     "room_size_incl_terrace": "False",
#                     "views": null,
#                     "max_extrabeds": "1",
#                     "max_infant_in_room": "0",
#                     "hotel_room_type_picture": "https://pix8.agoda.net/property/16075260/0/527c1a179a675d5d3a28e7146901da6b.jpeg?ce=0&s=312x",
#                     "bed_type": null,
#                     "hotel_master_room_type_id": "345007343",
#                     "hotel_room_type_alternate_name": null,
#                     "shared_bathroom": "False",
#                     "gender": null
#                 },
#                 {
#                     "hotel_id": "16075260",
#                     "hotel_room_type_id": "856851070",
#                     "standard_caption": "Delight Family Suite",
#                     "standard_caption_translated": "Delight Family Suite",
#                     "max_occupancy_per_room": "2",
#                     "no_of_room": "0",
#                     "size_of_room": "0",
#                     "room_size_incl_terrace": "False",
#                     "views": null,
#                     "max_extrabeds": "1",
#                     "max_infant_in_room": "0",
#                     "hotel_room_type_picture": "https://pix8.agoda.net/property/16075260/0/527c1a179a675d5d3a28e7146901da6b.jpeg?ce=0&s=312x",
#                     "bed_type": "2 single beds",
#                     "hotel_master_room_type_id": "0",
#                     "hotel_room_type_alternate_name": null,
#                     "shared_bathroom": "False",
#                     "gender": null
#                 },
#                 {
#                     "hotel_id": "16075260",
#                     "hotel_room_type_id": "613400932",
#                     "standard_caption": "Executive Room (2 beds)",
#                     "standard_caption_translated": "Executive Room (2 beds)",
#                     "max_occupancy_per_room": "2",
#                     "no_of_room": "0",
#                     "size_of_room": "40",
#                     "room_size_incl_terrace": "False",
#                     "views": null,
#                     "max_extrabeds": "1",
#                     "max_infant_in_room": "0",
#                     "hotel_room_type_picture": "https://pix8.agoda.net/property/16075260/338771126/0a2d98da5d5358ea4e230d58ee5df3c9.jpg?ce=0&s=312x",
#                     "bed_type": "2 single beds",
#                     "hotel_master_room_type_id": "338771126",
#                     "hotel_room_type_alternate_name": null,
#                     "shared_bathroom": "False",
#                     "gender": null
#                 },
#                 {
#                     "hotel_id": "16075260",
#                     "hotel_room_type_id": "345058799",
#                     "standard_caption": "Boutique Business Double Room",
#                     "standard_caption_translated": null,
#                     "max_occupancy_per_room": "2",
#                     "no_of_room": "0",
#                     "size_of_room": "0",
#                     "room_size_incl_terrace": "False",
#                     "views": null,
#                     "max_extrabeds": "1",
#                     "max_infant_in_room": "0",
#                     "hotel_room_type_picture": "https://pix8.agoda.net/property/16075260/0/527c1a179a675d5d3a28e7146901da6b.jpeg?ce=0&s=312x",
#                     "bed_type": null,
#                     "hotel_master_room_type_id": "0",
#                     "hotel_room_type_alternate_name": null,
#                     "shared_bathroom": "False",
#                     "gender": null
#                 },
#                 {
#                     "hotel_id": "16075260",
#                     "hotel_room_type_id": "613401307",
#                     "standard_caption": "Boutique Business Double Room",
#                     "standard_caption_translated": null,
#                     "max_occupancy_per_room": "2",
#                     "no_of_room": "0",
#                     "size_of_room": "0",
#                     "room_size_incl_terrace": "False",
#                     "views": null,
#                     "max_extrabeds": "1",
#                     "max_infant_in_room": "0",
#                     "hotel_room_type_picture": "https://pix8.agoda.net/property/16075260/0/527c1a179a675d5d3a28e7146901da6b.jpeg?ce=0&s=312x",
#                     "bed_type": null,
#                     "hotel_master_room_type_id": "345058799",
#                     "hotel_room_type_alternate_name": null,
#                     "shared_bathroom": "False",
#                     "gender": null
#                 },
#                 {
#                     "hotel_id": "16075260",
#                     "hotel_room_type_id": "809782325",
#                     "standard_caption": "Premier Deluxe Suite",
#                     "standard_caption_translated": "Premier Deluxe Suite",
#                     "max_occupancy_per_room": "2",
#                     "no_of_room": "0",
#                     "size_of_room": "0",
#                     "room_size_incl_terrace": "False",
#                     "views": null,
#                     "max_extrabeds": "1",
#                     "max_infant_in_room": "0",
#                     "hotel_room_type_picture": "https://pix8.agoda.net/property/16075260/0/527c1a179a675d5d3a28e7146901da6b.jpeg?ce=0&s=312x",
#                     "bed_type": null,
#                     "hotel_master_room_type_id": "0",
#                     "hotel_room_type_alternate_name": null,
#                     "shared_bathroom": "False",
#                     "gender": null
#                 },
#                 {
#                     "hotel_id": "16075260",
#                     "hotel_room_type_id": "345062458",
#                     "standard_caption": "Boutique Business Room - Double Occupancy",
#                     "standard_caption_translated": null,
#                     "max_occupancy_per_room": "2",
#                     "no_of_room": "0",
#                     "size_of_room": "0",
#                     "room_size_incl_terrace": "False",
#                     "views": null,
#                     "max_extrabeds": "1",
#                     "max_infant_in_room": "0",
#                     "hotel_room_type_picture": "https://pix8.agoda.net/property/16075260/0/527c1a179a675d5d3a28e7146901da6b.jpeg?ce=0&s=312x",
#                     "bed_type": null,
#                     "hotel_master_room_type_id": "0",
#                     "hotel_room_type_alternate_name": null,
#                     "shared_bathroom": "False",
#                     "gender": null
#                 },
#                 {
#                     "hotel_id": "16075260",
#                     "hotel_room_type_id": "613408742",
#                     "standard_caption": "Boutique Business Room - Double Occupancy",
#                     "standard_caption_translated": null,
#                     "max_occupancy_per_room": "2",
#                     "no_of_room": "0",
#                     "size_of_room": "0",
#                     "room_size_incl_terrace": "False",
#                     "views": null,
#                     "max_extrabeds": "1",
#                     "max_infant_in_room": "0",
#                     "hotel_room_type_picture": "https://pix8.agoda.net/property/16075260/0/527c1a179a675d5d3a28e7146901da6b.jpeg?ce=0&s=312x",
#                     "bed_type": null,
#                     "hotel_master_room_type_id": "345062458",
#                     "hotel_room_type_alternate_name": null,
#                     "shared_bathroom": "False",
#                     "gender": null
#                 },
#                 {
#                     "hotel_id": "16075260",
#                     "hotel_room_type_id": "757410708",
#                     "standard_caption": "Delight Family Suite",
#                     "standard_caption_translated": "Delight Family Suite",
#                     "max_occupancy_per_room": "2",
#                     "no_of_room": "0",
#                     "size_of_room": "0",
#                     "room_size_incl_terrace": "False",
#                     "views": null,
#                     "max_extrabeds": "1",
#                     "max_infant_in_room": "0",
#                     "hotel_room_type_picture": "https://pix8.agoda.net/property/16075260/0/527c1a179a675d5d3a28e7146901da6b.jpeg?ce=0&s=312x",
#                     "bed_type": null,
#                     "hotel_master_room_type_id": "0",
#                     "hotel_room_type_alternate_name": null,
#                     "shared_bathroom": "False",
#                     "gender": null
#                 }
#             ]
#         }
#     }
# }

# %%
if response.status_code == 200:
    xml_data = response.content
    print(xml_data)

# %%
data_dict = xmltodict.parse(xml_data)

# Convert OrderedDict to JSON
json_data = json.dumps(data_dict, indent=4)
print(json_data)
# Out:
# {
#     "Hotel_feed_full": {
#         "@xmlns:xs": "http://www.w3.org/2001/XMLSchema",
#         "@xmlns:xsi": "http://www.w3.org/2001/XMLSchema-instance",
#         "hotels": {
#             "hotel": {
#                 "hotel_id": "1000052",
#                 "hotel_name": "Pousada Aquarela Pirenopolis",
#                 "hotel_formerly_name": null,
#                 "translated_name": "Pousada Aquarela Pirenopolis",
#                 "star_rating": "2.0",
#                 "continent_id": "8",
#                 "country_id": "207",
#                 "city_id": "669242",
#                 "area_id": "537409",
#                 "longitude": "-48.960330963134766",
#                 "latitude": "-15.844820022583008",
#                 "hotel_url": "https://www.agoda.com/partners/partnersearch.aspx?hid=1000052",
#                 "popularity_score": "954760",
#                 "remark": "Please note that both swimming pools are under renovation and they won\u00b4t be working temporarily.Please inform  in advance of your expected arrival time. You can use the Special Requests box when booking, or contact the property directly with the contact details provided in your confirmation.Payment before arrival via bank transfer is required. The property will contact you after you book to provide instructions.This property may host on-site functions and some rooms may be affected by noise.This property will not accommodate hen, stag or similar parties.This property is located in a residential area and guests are asked to refrain from excessive noise.Guests are required to show a photo identification and credit card upon check-in. Please note that all Special Requests are subject to availability and additional charges may apply.",
#                 "number_of_reviews": "2",
#                 "rating_average": "6.8",
#                 "child_and_extra_bed_policy": {
#                     "infant_age": "0",
#                     "children_age_from": "0",
#                     "children_age_to": "5",
#                     "children_stay_free": "true",
#                     "min_guest_age": "0"
#                 },
#                 "accommodation_type": "Hotel",
#                 "nationality_restrictions": null
#             }
#         },
#         "addresses": {
#             "address": [
#                 {
#                     "hotel_id": "1000052",
#                     "address_type": "English address",
#                     "address_line_1": "Rua 07, Quadra 29, Lote 37 - Bairro Alto do Carmo",
#                     "address_line_2": null,
#                     "postal_code": "72980-000",
#                     "state": "Goias",
#                     "city": "Pirenopolis",
#                     "country": "Brazil"
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "address_type": "Local language",
#                     "address_line_1": null,
#                     "address_line_2": null,
#                     "postal_code": null,
#                     "state": "Goi\u00e1s",
#                     "city": "Piren\u00f3polis",
#                     "country": "Brasil"
#                 }
#             ]
#         },
#         "hotel_descriptions": {
#             "hotel_description": {
#                 "hotel_id": "1000052",
#                 "overview": null,
#                 "snippet": null
#             }
#         },
#         "facilities": {
#             "facility": [
#                 {
#                     "hotel_id": "1000052",
#                     "property_group_description": "Languages spoken",
#                     "property_id": "177",
#                     "property_name": "Portuguese",
#                     "property_translated_name": "Portuguese"
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "property_group_description": "Internet access",
#                     "property_id": "109",
#                     "property_name": "Free Wi-Fi in all rooms!",
#                     "property_translated_name": "Free Wi-Fi in all rooms!"
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "property_group_description": "Internet access",
#                     "property_id": "90",
#                     "property_name": "Internet",
#                     "property_translated_name": "Internet"
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "property_group_description": "Internet access",
#                     "property_id": "2578",
#                     "property_name": "Internet services",
#                     "property_translated_name": "Internet services"
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "property_group_description": "Internet access",
#                     "property_id": "79",
#                     "property_name": "Wi-Fi in public areas",
#                     "property_translated_name": "Wi-Fi in public areas"
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "property_group_description": "Things to do, ways to relax",
#                     "property_id": "68",
#                     "property_name": "Garden",
#                     "property_translated_name": "Garden"
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "property_group_description": "Things to do, ways to relax",
#                     "property_id": "132",
#                     "property_name": "Solarium",
#                     "property_translated_name": "Solarium"
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "property_group_description": "Things to do, ways to relax",
#                     "property_id": "61",
#                     "property_name": "Spa",
#                     "property_translated_name": "Spa"
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "property_group_description": "Things to do, ways to relax",
#                     "property_id": "91",
#                     "property_name": "Spa/sauna",
#                     "property_translated_name": "Spa/sauna"
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "property_group_description": "Cleanliness and safety",
#                     "property_id": "2517",
#                     "property_name": "Anti-viral cleaning products",
#                     "property_translated_name": "Anti-viral cleaning products"
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "property_group_description": "Cleanliness and safety",
#                     "property_id": "2367",
#                     "property_name": "Body thermometer",
#                     "property_translated_name": "Body thermometer"
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "property_group_description": "Cleanliness and safety",
#                     "property_id": "2513",
#                     "property_name": "Cashless payment service",
#                     "property_translated_name": "Cashless payment service"
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "property_group_description": "Cleanliness and safety",
#                     "property_id": "2371",
#                     "property_name": "Doctor/nurse on call",
#                     "property_translated_name": "Doctor/nurse on call"
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "property_group_description": "Cleanliness and safety",
#                     "property_id": "2373",
#                     "property_name": "First aid kit",
#                     "property_translated_name": "First aid kit"
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "property_group_description": "Cleanliness and safety",
#                     "property_id": "2375",
#                     "property_name": "Free face masks",
#                     "property_translated_name": "Free face masks"
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "property_group_description": "Cleanliness and safety",
#                     "property_id": "2519",
#                     "property_name": "Guest rooms seal after sanitization",
#                     "property_translated_name": "Guest rooms seal after sanitization"
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "property_group_description": "Cleanliness and safety",
#                     "property_id": "2376",
#                     "property_name": "Hand sanitizer",
#                     "property_translated_name": "Hand sanitizer"
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "property_group_description": "Cleanliness and safety",
#                     "property_id": "2511",
#                     "property_name": "Hot water linen and laundry washing",
#                     "property_translated_name": "Hot water linen and laundry washing"
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "property_group_description": "Cleanliness and safety",
#                     "property_id": "2509",
#                     "property_name": "Individually-wrapped food options",
#                     "property_translated_name": "Individually-wrapped food options"
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "property_group_description": "Cleanliness and safety",
#                     "property_id": "2398",
#                     "property_name": "Physical distancing of at least 1 meter",
#                     "property_translated_name": "Physical distancing of at least 1 meter"
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "property_group_description": "Cleanliness and safety",
#                     "property_id": "2520",
#                     "property_name": "Professional-grade sanitizing services",
#                     "property_translated_name": "Professional-grade sanitizing services"
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "property_group_description": "Cleanliness and safety",
#                     "property_id": "2396",
#                     "property_name": "Protective screens in common areas",
#                     "property_translated_name": "Protective screens in common areas"
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "property_group_description": "Cleanliness and safety",
#                     "property_id": "2521",
#                     "property_name": "Room sanitization opt-out available",
#                     "property_translated_name": "Room sanitization opt-out available"
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "property_group_description": "Cleanliness and safety",
#                     "property_id": "2518",
#                     "property_name": "Rooms sanitized between stays",
#                     "property_translated_name": "Rooms sanitized between stays"
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "property_group_description": "Cleanliness and safety",
#                     "property_id": "2399",
#                     "property_name": "Safe dining setup",
#                     "property_translated_name": "Safe dining setup"
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "property_group_description": "Cleanliness and safety",
#                     "property_id": "2507",
#                     "property_name": "Sanitized kitchen and tableware items",
#                     "property_translated_name": "Sanitized kitchen and tableware items"
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "property_group_description": "Cleanliness and safety",
#                     "property_id": "2512",
#                     "property_name": "Shared stationery removed",
#                     "property_translated_name": "Shared stationery removed"
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "property_group_description": "Cleanliness and safety",
#                     "property_id": "2381",
#                     "property_name": "Staff trained in safety protocol",
#                     "property_translated_name": "Staff trained in safety protocol"
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "property_group_description": "Cleanliness and safety",
#                     "property_id": "2380",
#                     "property_name": "Temperature check for guests and staff",
#                     "property_translated_name": "Temperature check for guests and staff"
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "property_group_description": "Services and conveniences",
#                     "property_id": "2575",
#                     "property_name": "Air conditioning in public area",
#                     "property_translated_name": "Air conditioning in public area"
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "property_group_description": "Services and conveniences",
#                     "property_id": "2368",
#                     "property_name": "Contactless check-in/out",
#                     "property_translated_name": "Contactless check-in/out"
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "property_group_description": "Services and conveniences",
#                     "property_id": "2574",
#                     "property_name": "Invoice provided",
#                     "property_translated_name": "Invoice provided"
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "property_group_description": "Services and conveniences",
#                     "property_id": "129",
#                     "property_name": "Shared lounge/TV area",
#                     "property_translated_name": "Shared lounge/TV area"
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "property_group_description": "Services and conveniences",
#                     "property_id": "83",
#                     "property_name": "Smoking area",
#                     "property_translated_name": "Smoking area"
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "property_group_description": "Services and conveniences",
#                     "property_id": "2572",
#                     "property_name": "Terrace",
#                     "property_translated_name": "Terrace"
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "property_group_description": "For the kids",
#                     "property_id": "81",
#                     "property_name": "Family room",
#                     "property_translated_name": "Family room"
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "property_group_description": "For the kids",
#                     "property_id": "2529",
#                     "property_name": "Kids meal",
#                     "property_translated_name": "Kids meal"
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "property_group_description": "Access",
#                     "property_id": "251",
#                     "property_name": "Check-in/out [private]",
#                     "property_translated_name": "Check-in/out [private]"
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "property_group_description": "Access",
#                     "property_id": "2573",
#                     "property_name": "Fire extinguisher",
#                     "property_translated_name": "Fire extinguisher"
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "property_group_description": "Access",
#                     "property_id": "2577",
#                     "property_name": "Non-smoking rooms",
#                     "property_translated_name": "Non-smoking rooms"
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "property_group_description": "Access",
#                     "property_id": "24",
#                     "property_name": "Pets allowed",
#                     "property_translated_name": "Pets allowed"
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "property_group_description": "Available in all rooms",
#                     "property_id": "25",
#                     "property_name": "Air conditioning",
#                     "property_translated_name": "Air conditioning"
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "property_group_description": "Available in all rooms",
#                     "property_id": "210",
#                     "property_name": "Clothes rack",
#                     "property_translated_name": "Clothes rack"
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "property_group_description": "Available in all rooms",
#                     "property_id": "2679",
#                     "property_name": "Hand sanitizer",
#                     "property_translated_name": "Hand sanitizer"
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "property_group_description": "Available in all rooms",
#                     "property_id": "2383",
#                     "property_name": "Individual air conditioning",
#                     "property_translated_name": "Individual air conditioning"
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "property_group_description": "Available in all rooms",
#                     "property_id": "34",
#                     "property_name": "In-room safe box",
#                     "property_translated_name": "In-room safe box"
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "property_group_description": "Available in all rooms",
#                     "property_id": "220",
#                     "property_name": "Linens",
#                     "property_translated_name": "Linens"
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "property_group_description": "Available in all rooms",
#                     "property_id": "40",
#                     "property_name": "Mini bar",
#                     "property_translated_name": "Mini bar"
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "property_group_description": "Available in all rooms",
#                     "property_id": "338",
#                     "property_name": "Private bathroom",
#                     "property_translated_name": "Private bathroom"
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "property_group_description": "Available in all rooms",
#                     "property_id": "38",
#                     "property_name": "Shower",
#                     "property_translated_name": "Shower"
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "property_group_description": "Available in all rooms",
#                     "property_id": "2643",
#                     "property_name": "Sleep comfort items",
#                     "property_translated_name": "Sleep comfort items"
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "property_group_description": "Available in all rooms",
#                     "property_id": "2668",
#                     "property_name": "Socket near the bed",
#                     "property_translated_name": "Socket near the bed"
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "property_group_description": "Available in all rooms",
#                     "property_id": "2365",
#                     "property_name": "Streaming service like Netflix",
#                     "property_translated_name": "Streaming service like Netflix"
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "property_group_description": "Available in all rooms",
#                     "property_id": "141",
#                     "property_name": "Toiletries",
#                     "property_translated_name": "Toiletries"
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "property_group_description": "Available in all rooms",
#                     "property_id": "2665",
#                     "property_name": "Trash cans",
#                     "property_translated_name": "Trash cans"
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "property_group_description": "Available in all rooms",
#                     "property_id": "36",
#                     "property_name": "TV [flat screen]",
#                     "property_translated_name": "TV [flat screen]"
#                 }
#             ]
#         },
#         "pictures": {
#             "picture": [
#                 {
#                     "hotel_id": "1000052",
#                     "picture_id": "6365845",
#                     "caption": "Swimming pool",
#                     "caption_translated": "Swimming pool",
#                     "URL": "https://q-xx.bstatic.com/xdata/images/hotel/max500/291642468.jpg?k=75627f62444a2eb0da567443b0b875d121aff01b362999fda7e90ae2d878475f&o=&s=312x"
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "picture_id": "250564779",
#                     "caption": null,
#                     "caption_translated": null,
#                     "URL": "https://q-xx.bstatic.com/xdata/images/hotel/max500/292041528.jpg?k=6dac759b7879619aab31b21dcff2078da16905a084eee18e89a3957cdaddd95c&o=&s=312x"
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "picture_id": "261023604",
#                     "caption": "Entrance",
#                     "caption_translated": "Entrance",
#                     "URL": "https://q-xx.bstatic.com/xdata/images/hotel/max500/300831137.jpg?k=63c171647c78fee8b6a0f3a23d3da0f197d5e962e57d5cd78df43dfec3ffb260&o=&s=312x"
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "picture_id":

#                     "standard_caption_translated": null,
#                     "max_occupancy_per_room": "2",
#                     "no_of_room": "0",
#                     "size_of_room": "0",
#                     "room_size_incl_terrace": "False",
#                     "views": null,
#                     "max_extrabeds": "1",
#                     "max_infant_in_room": "0",
#                     "hotel_room_type_picture": "https://q-xx.bstatic.com/xdata/images/hotel/max500/291642468.jpg?k=75627f62444a2eb0da567443b0b875d121aff01b362999fda7e90ae2d878475f&o=&s=312x",
#                     "bed_type": null,
#                     "hotel_master_room_type_id": "286954285",
#                     "hotel_room_type_alternate_name": null,
#                     "shared_bathroom": "False",
#                     "gender": null
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "hotel_room_type_id": "373864715",
#                     "standard_caption": "Triple Room Suite",
#                     "standard_caption_translated": null,
#                     "max_occupancy_per_room": "2",
#                     "no_of_room": "0",
#                     "size_of_room": "0",
#                     "room_size_incl_terrace": "False",
#                     "views": null,
#                     "max_extrabeds": "1",
#                     "max_infant_in_room": "0",
#                     "hotel_room_type_picture": "https://q-xx.bstatic.com/xdata/images/hotel/max500/291642468.jpg?k=75627f62444a2eb0da567443b0b875d121aff01b362999fda7e90ae2d878475f&o=&s=312x",
#                     "bed_type": null,
#                     "hotel_master_room_type_id": "286954285",
#                     "hotel_room_type_alternate_name": null,
#                     "shared_bathroom": "False",
#                     "gender": null
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "hotel_room_type_id": "32933497",
#                     "standard_caption": "Triple Room",
#                     "standard_caption_translated": null,
#                     "max_occupancy_per_room": "3",
#                     "no_of_room": "0",
#                     "size_of_room": "0",
#                     "room_size_incl_terrace": "False",
#                     "views": null,
#                     "max_extrabeds": "0",
#                     "max_infant_in_room": "0",
#                     "hotel_room_type_picture": "https://q-xx.bstatic.com/xdata/images/hotel/max500/291642468.jpg?k=75627f62444a2eb0da567443b0b875d121aff01b362999fda7e90ae2d878475f&o=&s=312x",
#                     "bed_type": null,
#                     "hotel_master_room_type_id": "0",
#                     "hotel_room_type_alternate_name": null,
#                     "shared_bathroom": "False",
#                     "gender": null
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "hotel_room_type_id": "364776742",
#                     "standard_caption": "Triple Room",
#                     "standard_caption_translated": null,
#                     "max_occupancy_per_room": "3",
#                     "no_of_room": "0",
#                     "size_of_room": "0",
#                     "room_size_incl_terrace": "False",
#                     "views": null,
#                     "max_extrabeds": "0",
#                     "max_infant_in_room": "0",
#                     "hotel_room_type_picture": "https://q-xx.bstatic.com/xdata/images/hotel/max500/291642468.jpg?k=75627f62444a2eb0da567443b0b875d121aff01b362999fda7e90ae2d878475f&o=&s=312x",
#                     "bed_type": null,
#                     "hotel_master_room_type_id": "32933497",
#                     "hotel_room_type_alternate_name": null,
#                     "shared_bathroom": "False",
#                     "gender": null
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "hotel_room_type_id": "373864714",
#                     "standard_caption": "Triple Room",
#                     "standard_caption_translated": null,
#                     "max_occupancy_per_room": "3",
#                     "no_of_room": "0",
#                     "size_of_room": "0",
#                     "room_size_incl_terrace": "False",
#                     "views": null,
#                     "max_extrabeds": "0",
#                     "max_infant_in_room": "0",
#                     "hotel_room_type_picture": "https://q-xx.bstatic.com/xdata/images/hotel/max500/291642468.jpg?k=75627f62444a2eb0da567443b0b875d121aff01b362999fda7e90ae2d878475f&o=&s=312x",
#                     "bed_type": null,
#                     "hotel_master_room_type_id": "32933497",
#                     "hotel_room_type_alternate_name": null,
#                     "shared_bathroom": "False",
#                     "gender": null
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "hotel_room_type_id": "147238876",
#                     "standard_caption": "Quadruple Room with Private Bathroom",
#                     "standard_caption_translated": "Quadruple Room with Private Bathroom",
#                     "max_occupancy_per_room": "4",
#                     "no_of_room": "0",
#                     "size_of_room": "1.49",
#                     "room_size_incl_terrace": "False",
#                     "views": "Mountain view",
#                     "max_extrabeds": "0",
#                     "max_infant_in_room": "0",
#                     "hotel_room_type_picture": "https://q-xx.bstatic.com/xdata/images/hotel/max500/291906250.jpg?k=5f5cb0898a8ccdafd25b26827e85671e8e75df5bc04276e83d903dc43d84854a&o=&s=312x",
#                     "bed_type": null,
#                     "hotel_master_room_type_id": "0",
#                     "hotel_room_type_alternate_name": null,
#                     "shared_bathroom": "False",
#                     "gender": null
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "hotel_room_type_id": "364776739",
#                     "standard_caption": "Suite Casal",
#                     "standard_caption_translated": null,
#                     "max_occupancy_per_room": "2",
#                     "no_of_room": "0",
#                     "size_of_room": "0",
#                     "room_size_incl_terrace": "False",
#                     "views": null,
#                     "max_extrabeds": "1",
#                     "max_infant_in_room": "0",
#                     "hotel_room_type_picture": "https://q-xx.bstatic.com/xdata/images/hotel/max500/291642468.jpg?k=75627f62444a2eb0da567443b0b875d121aff01b362999fda7e90ae2d878475f&o=&s=312x",
#                     "bed_type": null,
#                     "hotel_master_room_type_id": "286954282",
#                     "hotel_room_type_alternate_name": null,
#                     "shared_bathroom": "False",
#                     "gender": null
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "hotel_room_type_id": "373864712",
#                     "standard_caption": "Suite Casal",
#                     "standard_caption_translated": null,
#                     "max_occupancy_per_room": "2",
#                     "no_of_room": "0",
#                     "size_of_room": "0",
#                     "room_size_incl_terrace": "False",
#                     "views": null,
#                     "max_extrabeds": "1",
#                     "max_infant_in_room": "0",
#                     "hotel_room_type_picture": "https://q-xx.bstatic.com/xdata/images/hotel/max500/291642468.jpg?k=75627f62444a2eb0da567443b0b875d121aff01b362999fda7e90ae2d878475f&o=&s=312x",
#                     "bed_type": null,
#                     "hotel_master_room_type_id": "286954282",
#                     "hotel_room_type_alternate_name": null,
#                     "shared_bathroom": "False",
#                     "gender": null
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "hotel_room_type_id": "210486781",
#                     "standard_caption": "Double Standard",
#                     "standard_caption_translated": null,
#                     "max_occupancy_per_room": "3",
#                     "no_of_room": "0",
#                     "size_of_room": "0",
#                     "room_size_incl_terrace": "False",
#                     "views": null,
#                     "max_extrabeds": "1",
#                     "max_infant_in_room": "0",
#                     "hotel_room_type_picture": "https://q-xx.bstatic.com/xdata/images/hotel/max500/291642468.jpg?k=75627f62444a2eb0da567443b0b875d121aff01b362999fda7e90ae2d878475f&o=&s=312x",
#                     "bed_type": null,
#                     "hotel_master_room_type_id": "0",
#                     "hotel_room_type_alternate_name": null,
#                     "shared_bathroom": "False",
#                     "gender": null
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "hotel_room_type_id": "364776730",
#                     "standard_caption": "Double Standard",
#                     "standard_caption_translated": null,
#                     "max_occupancy_per_room": "3",
#                     "no_of_room": "0",
#                     "size_of_room": "0",
#                     "room_size_incl_terrace": "False",
#                     "views": null,
#                     "max_extrabeds": "1",
#                     "max_infant_in_room": "0",
#                     "hotel_room_type_picture": "https://q-xx.bstatic.com/xdata/images/hotel/max500/291642468.jpg?k=75627f62444a2eb0da567443b0b875d121aff01b362999fda7e90ae2d878475f&o=&s=312x",
#                     "bed_type": null,
#                     "hotel_master_room_type_id": "210486781",
#                     "hotel_room_type_alternate_name": null,
#                     "shared_bathroom": "False",
#                     "gender": null
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "hotel_room_type_id": "373864709",
#                     "standard_caption": "Double Standard",
#                     "standard_caption_translated": null,
#                     "max_occupancy_per_room": "3",
#                     "no_of_room": "0",
#                     "size_of_room": "0",
#                     "room_size_incl_terrace": "False",
#                     "views": null,
#                     "max_extrabeds": "1",
#                     "max_infant_in_room": "0",
#                     "hotel_room_type_picture": "https://q-xx.bstatic.com/xdata/images/hotel/max500/291642468.jpg?k=75627f62444a2eb0da567443b0b875d121aff01b362999fda7e90ae2d878475f&o=&s=312x",
#                     "bed_type": null,
#                     "hotel_master_room_type_id": "210486781",
#                     "hotel_room_type_alternate_name": null,
#                     "shared_bathroom": "False",
#                     "gender": null
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "hotel_room_type_id": "147238873",
#                     "standard_caption": "Double Room with Private Bathroom",
#                     "standard_caption_translated": "Double Room with Private Bathroom",
#                     "max_occupancy_per_room": "2",
#                     "no_of_room": "0",
#                     "size_of_room": "1.11",
#                     "room_size_incl_terrace": "False",
#                     "views": "Garden view",
#                     "max_extrabeds": "0",
#                     "max_infant_in_room": "0",
#                     "hotel_room_type_picture": "https://q-xx.bstatic.com/xdata/images/hotel/max500/291918538.jpg?k=3b8d8ec7abb464009f1138143c71e7925bb9ad4e307840da55ddd67673ae470c&o=&s=312x",
#                     "bed_type": null,
#                     "hotel_master_room_type_id": "0",
#                     "hotel_room_type_alternate_name": null,
#                     "shared_bathroom": "False",
#                     "gender": null
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "hotel_room_type_id": "364776741",
#                     "standard_caption": "Suite Quadruple Room",
#                     "standard_caption_translated": null,
#                     "max_occupancy_per_room": "2",
#                     "no_of_room": "0",
#                     "size_of_room": "0",
#                     "room_size_incl_terrace": "False",
#                     "views": null,
#                     "max_extrabeds": "1",
#                     "max_infant_in_room": "0",
#                     "hotel_room_type_picture": "https://q-xx.bstatic.com/xdata/images/hotel/max500/291642468.jpg?k=75627f62444a2eb0da567443b0b875d121aff01b362999fda7e90ae2d878475f&o=&s=312x",
#                     "bed_type": null,
#                     "hotel_master_room_type_id": "286954283",
#                     "hotel_room_type_alternate_name": null,
#                     "shared_bathroom": "False",
#                     "gender": null
#                 },
#                 {
#                     "hotel_id": "1000052",
#                     "hotel_room_type_id": "373864713",
#                     "standard_caption": "Suite Quadruple Room",
#                     "standard_caption_translated": null,
#                     "max_occupancy_per_room": "2",
#                     "no_of_room": "0",
#                     "size_of_room": "0",
#                     "room_size_incl_terrace": "False",
#                     "views": null,
#                     "max_extrabeds": "1",
#                     "max_infant_in_room": "0",
#                     "hotel_room_type_picture": "https://q-xx.bstatic.com/xdata/images/hotel/max500/291642468.jpg?k=75627f62444a2eb0da567443b0b875d121aff01b362999fda7e90ae2d878475f&o=&s=312x",
#                     "bed_type": null,
#                     "hotel_master_room_type_id": "286954283",
#                     "hotel_room_type_alternate_name": null,
#                     "shared_bathroom": "False",
#                     "gender": null
#                 }
#             ]
#         }
#     }
# }

# %% [markdown]
# #### Here get dynamic data

# %%
specific_data = {
    "hotel_id": data_dict["Hotel_feed_full"]["hotels"]["hotel"]["hotel_id"],
    "name": data_dict["Hotel_feed_full"]["hotels"]["hotel"]["hotel_name"],
    "name_local": data_dict["Hotel_feed_full"]["hotels"]["hotel"]["translated_name"],
    "hotel_formerly_name": data_dict["Hotel_feed_full"]["hotels"]["hotel"]["translated_name"],
    "brand_text": "NULL",
    "property_type": data_dict["Hotel_feed_full"]["hotels"]["hotel"]["accommodation_type"],
    "star_rating": data_dict["Hotel_feed_full"]["hotels"]["hotel"]["star_rating"],
    "chain": "NULL",
    "brand": "NULL",
    "logo": "NULL",
    "primary_photo": "NULL",
    "review_rating": {   
        "source": "NULL",
        "number_of_reviews": data_dict["Hotel_feed_full"]["hotels"]["hotel"]["number_of_reviews"],
        "rating_average": data_dict["Hotel_feed_full"]["hotels"]["hotel"]["rating_average"],
        "popularity_score": data_dict["Hotel_feed_full"]["hotels"]["hotel"]["popularity_score"],
    },
    "policies": {
        "checkin": {
            "begin_time": "NULL",
            "end_time": "NULL",
            "instructions": "NULL",
            "min_age": "NULL",
        },
        "checkout": {
            "time": "NULL",
        },
        "fees": {
            "optional": "NULL",
        },
        "know_before_you_go": "NULL",
        "pets": [
            "Pets not allowed"
        ],
        "remark": "NULL",
        "child_and_extra_bed_policy": {
            "infant_age": data_dict["Hotel_feed_full"]["hotels"]["hotel"]["child_and_extra_bed_policy"]["infant_age"],
            "children_age_from": data_dict["Hotel_feed_full"]["hotels"]["hotel"]["child_and_extra_bed_policy"]["children_age_from"],
            "children_age_to": data_dict["Hotel_feed_full"]["hotels"]["hotel"]["child_and_extra_bed_policy"]["children_age_to"],
            "children_stay_free": data_dict["Hotel_feed_full"]["hotels"]["hotel"]["child_and_extra_bed_policy"]["children_stay_free"],
            "min_guest_age": data_dict["Hotel_feed_full"]["hotels"]["hotel"]["child_and_extra_bed_policy"]["min_guest_age"]
        },
        "nationality_restrictions": data_dict["Hotel_feed_full"]["hotels"]["hotel"]["nationality_restrictions"],
    },
    "address": {
        "latitude": data_dict["Hotel_feed_full"]["hotels"]["hotel"]["latitude"],
        "longitude": data_dict["Hotel_feed_full"]["hotels"]["hotel"]["longitude"],
        "address_line_1": data_dict["Hotel_feed_full"]["addresses"]["address"][0]["address_line_1"],
        "address_line_2": data_dict["Hotel_feed_full"]["addresses"]["address"][0]["address_line_2"],
        "city": data_dict["Hotel_feed_full"]["addresses"]["address"][0]["city"],
        "state": data_dict["Hotel_feed_full"]["addresses"]["address"][0]["state"],
        "country": data_dict["Hotel_feed_full"]["addresses"]["address"][0]["country"],
        "country_code": "NULL",
        "postal_code": data_dict["Hotel_feed_full"]["addresses"]["address"][0]["postal_code"],
        "full_address": "NULL",
        "google_map_site_link": "NULL",
        "local_lang": {
            "latitude": data_dict["Hotel_feed_full"]["hotels"]["hotel"]["latitude"],
            "longitude": data_dict["Hotel_feed_full"]["hotels"]["hotel"]["longitude"],
            "address_line_1": data_dict["Hotel_feed_full"]["addresses"]["address"][1]["address_line_1"],
            "address_line_2": data_dict["Hotel_feed_full"]["addresses"]["address"][1]["address_line_2"],
            "city": data_dict["Hotel_feed_full"]["addresses"]["address"][1]["city"],
            "state": data_dict["Hotel_feed_full"]["addresses"]["address"][1]["state"],
            "country": data_dict["Hotel_feed_full"]["addresses"]["address"][1]["country"],
            "country_code": "NULL",
            "postal_code": data_dict["Hotel_feed_full"]["addresses"]["address"][1]["postal_code"],
            "full_address": "NULL",
            "google_map_site_link": "NULL",
        },
        "mapping": {
            "continent_id": "NULL",
            "country_id": "NULL",
            "province_id": "NULL",
            "state_id": "NULL",
            "city_id": "NULL",
            "area_id": "NULL"
        }
    },
    "contacts": {
        "phone_numbers": [],
        "fax": "NULL",
        "email_address": "NULL",
        "website": "NULL"
    },
    "descriptions": [
        {
            "title": "NULL",
            "text": "NULL"
        }
    ],
    "room_type": [],

    "spoken_languages": [],

    "amenities": [],
    
    "facilities": [],

    "hotel_photo": [],

    "point_of_interests": [],

    "nearest_airports": [],

    "train_stations": [],

    "connected_locations": [],

    "stadiums": []    
}

room_types = data_dict["Hotel_feed_full"]["roomtypes"]["roomtype"]
for room in room_types:
    room_data = {
        "room_id": room.get("hotel_room_type_id", "NULL"),
        "title": room.get("standard_caption", "NULL"),
        "title_lang": room.get("standard_caption", "NULL"),
        "room_pic": room.get("hotel_room_type_picture", "NULL"),
        "description": "NULL",
        "max_allowed": {
            "total": int(room.get("max_occupancy_per_room", 0)),
            "adults": int(room.get("max_occupancy_per_room", 0)),
            "children": "NULL",
            "infant": room.get("max_infant_in_room", "NULL"),
        },
        "no_of_room": room.get("no_of_room", "NULL"),
        "room_size": room.get("size_of_room", 0),
        "bed_type": [
            {
                "description": room.get("bed_type", "NULL"),
                "configuration": [],
                "max_extrabeds": room.get("max_extrabeds", "NULL"),
            }
        ],
        "shared_bathroom": room.get("shared_bathroom", "NULL"),
    }
    specific_data["room_type"].append(room_data)


facilities_types = data_dict["Hotel_feed_full"]["facilities"]["facility"]
for facility in facilities_types:
    facilities_data = {
        "type": facility.get("property_name", "NULL"),
        "title": facility.get("property_group_description", "NULL"),
        "icon": facility.get("property_translated_name", "NULL")
    }
    specific_data["facilities"].append(facilities_data)


hotel_photo_data = data_dict["Hotel_feed_full"]["pictures"]["picture"]
for photo in hotel_photo_data:
    hotel_photo_data = {  
        "picture_id": photo.get("picture_id", "NULL"),
        "title": photo.get("caption", "NULL"),
        "url": photo.get("URL", "NULL")
    }
    specific_data["hotel_photo"].append(hotel_photo_data)
    

print(specific_data)

# %%
try:
    # Assuming specific_data is correctly populated
    with open("specific_data.json", "w") as json_file:
        json.dump(specific_data, json_file, indent=4)
    print("Data saved to specific_data.json")
except TypeError as e:
    print(f"Serialization error: {e}")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Data saved to specific_data.json
